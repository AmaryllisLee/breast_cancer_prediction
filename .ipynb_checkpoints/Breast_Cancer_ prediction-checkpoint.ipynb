# %% [markdown]
# <h1>TeTe (TEKAM): Het voorspellinsmodel voor borstkanker(Breast Cancer prediction)</h1>
#
# <i>Verder in dit document wordt verwezen naar het voorspellingsmodel voor borstkanker als TeTe.</i>
# Het voorspellingsmodel voor borstkanker is bedoeld om door middel van een statistische model na te gaan hoe nauwkeurig  de diagnose is. De dataset bestaat uit gegevens van verschillende patienten en dient eerst voorbereid en geanalyseerd te worden. Voor de nauwkeurigheid wordt gebruikt gemaakt van een confusion matrix. Het resultaat wordt gepresenteerd in een tabel en gevisualiseerd in een heatmap.
#
# De algoritme is bedoeld om op basis van de eigenschappen (features) van een cel van de borstmassa, de diagnose van borstkanker van patienten te voorspellen.

# %% [markdown]
# ## Voorbereiden en verkennen van de dataset

# %% [markdown]
# ### Importeren van de benodigde libraries.
# <p>Voor het uitvoeren van de algoritme wordt gebruik gemaakt van verschillende libraries. Als eerst wordt deze libraries geimporteerd.</p>

# %%
#Libraries 
import numpy as np 
import pandas as pd 


#Deze plotting libraries zijjn gebruikt om bepaalde gedeelte van de code te visualiseren
import matplotlib.pyplot as plt 
import seaborn as sns 
# plots wordt getoond in de notebook
# %matplotlib inline

import random # gebruikt om de dataset te splitsen

# %% [markdown]
# ### Dataset
# <p>Er wordt voor dit dataset gebruikt gemaakt van
# <a href="https://www.kaggle.com/uciml/breast-cancer-wisconsin-data">de Breast Cancer Wisconsin (Diagnostic) Data Set.</a> Deze dataset bestaat uit de diagnose van de borstkanker en 30 eigenschappen van een cel aanwezig in de digitale beeld van een dunne naald (Fine Needle Aspirate (FNA)) van een borstmassa. Hieronder worden de attributen van de dataset weergegeven.
# </p>

# %% [markdown]
# <b>Attribute Information:</b><br>
# ID number<br>
# Diagnosis (M = malignant, B = benign)<br>
# <br>
# <b>Ten real-valued features are computed for each cell nucleus:</b><br>
# Radius (mean of distances from center to points on the perimeter)<br>
# Texture (standard deviation of gray-scale values)<br>
# Perimeter<br>
# Area<br>
# Smoothness (local variation in radius lengths)<br>
# Compactness (perimeter² / area — 1.0)<br>
# Concavity (severity of concave portions of the contour)<br>
# Concave points (number of concave portions of the contour)<br>
# Symmetry<br>
# Fractal dimension (“coastline approximation” — 1)<br>
#
# <br>
# The mean, standard error and “worst” or largest (mean of the three largest values) of these features were computed for each image, resulting in 30 features. For instance, field 3 is Mean Radius, field 13 is Radius SE, field 23 is Worst Radius

# %% [markdown]
# <p>
# Vervolgens wordt er een verkenning en een analyze van de dataset gedaan om de kwaliteit van de dataset te verhogen, zodat de nauwkeurigheid van de algoritme ook wordt verhoogd.
#
# Eerst wordt de dataset geimporteerd. Vervolgens wordt de eerste 10 rijen in de dataset geprint. </p>

# %%
#Load dataset(data .csv)
df = pd.read_csv("data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df = df.drop("id", axis =1) #verwijder de "id" kolom want die zullen we niet verder gaan gebruiken

# %%
#print de eerste 5 rijen van df
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0          0.4601                  0.11890          NaN
# 1          0.2750                  0.08902          NaN
# 2          0.3613                  0.08758          NaN
# 3          0.6638                  0.17300          NaN
# 4          0.2364                  0.07678          NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# <p>In de onderstaande tabel wordt een statische samenvatting gegeven van de dataset. </p>

# %%
#data describe 
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  texture_worst  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        concavity_worst  concave points_worst  symmetry_worst  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        fractal_dimension_worst  Unnamed: 32
# count               569.000000          0.0
# mean                  0.083946          NaN
# std                   0.018061          NaN
# min                   0.055040          NaN
# 25%                   0.071460          NaN
# 50%                   0.080040          NaN
# 75%                   0.092080          NaN
# max                   0.207500          NaN
#
# [8 rows x 31 columns]

# %% [markdown]
# <p>
#  Deze dataset bestaat uit 569 rijen en 33 kolommen. Dit betekent dat er data zijn van 569 patienten. Van elk patient die geidentifeerd is met een idnummer wordt een totaal van 30 eigenschappen (features) weergegeven.<br>
#  In deze dataset is te zien dat een patient kan worden gediagnoseerd met de volgende type cancer:
# <ul>
#      <li>Malign (M) : kwaadardige vorm van borstkanker</li>
#      <li>Belign (B): goedaardige vorm van borstkanker</li>
# </ul>
# Deze algoritme moet voor elke patient de diagnose gaat voorspellen op base van de 30 eigenschappen.<br>
# We gaan dus de kolom <i>diagnosis</i> voorspellen
#  </p>

# %%
#Dimensie aantonen van df => de aantal rijen , kolommen van df aangeven
df.shape
# Out:
# (569, 32)

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# Er is hier te zien dat deze dataset bestaat uit 357 patienten met goedaardig borstkanker en 212 patient met kwaadaardig borstkanker. Aan de hand van de volgende figuur wordt het resultaat gevisualiseerd.

# %%
sns.countplot(df['diagnosis'])

# %% [markdown]
# <p>In deze gedeelte gaan we alle missing or null data identificeren en verwijderen</p>

# %%
df.isnull().sum()
df.isna().sum()
# Out:
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df = df.dropna(axis = 1) # verwijder ale ontbrekende waardes, in deze dataset verwijder we de Unnamed kolom

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %% [markdown]
# <p>We hebben nu alle ontbrekende waarde verwijderen , de onnodige kolomen verwijderen("id", "Unnamed") en we hebben de dataset verkend.</p>

# %% [markdown]
# ## Dataset splitsen in training en test

# %% [markdown]
# Voor deze fase  gaan we de dataset splitsen in een training en testing dataset.

# %%
def split_dataset(df, test_size):
    'split dataset in training en testing dataset'
    if isinstance(test_size, float):
        test_size = round(test_size * len(df))
    
    rowIndex = df.index.tolist()# alle index van df in een lijst zetten
    testIndex = random.sample(population = rowIndex, k = test_size) # random aantal test_size rijen van df nemen
    
    test_df = df.loc[testIndex]
    train_df = df.drop(testIndex)
    
    return train_df, test_df

# %% [markdown]
# #### Dataset splitsen in een 75% training dataset en 25 % testing dataset

# %%
random.seed(5)
train_df , test_df = split_dataset(df, test_size= round(len(df)* 0.25))

# %%
train_df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38           122.8     1001.0
# 2         M        19.69         21.25           130.0     1203.0
# 6         M        18.25         19.98           119.6     1040.0
# 7         M        13.71         20.83            90.2      577.9
# 8         M        13.00         21.82            87.5      519.8
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840            0.2776         0.30010              0.14710
# 2          0.10960            0.1599         0.19740              0.12790
# 6          0.09463            0.1090         0.11270              0.07400
# 7          0.11890            0.1645         0.09366              0.05985
# 8          0.12730            0.1932         0.18590              0.09353
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
# 2         0.2069  ...         23.57          25.53            152.5
# 6         0.1794  ...         22.88          27.66            153.2
# 7         0.2196  ...         17.06          28.14            110.6
# 8         0.2350  ...         15.49          30.73            106.2
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 2      1709.0            0.1444             0.4245           0.4504
# 6      1606.0            0.1442             0.2576           0.3784
# 7       897.0            0.1654             0.3682           0.2678
# 8       739.3            0.1703             0.5401           0.5390
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 2                0.2430          0.3613                  0.08758
# 6                0.1932          0.3063                  0.08368
# 7                0.1556          0.3196                  0.11510
# 8                0.2060          0.4378                  0.10720
#
# [5 rows x 31 columns]

# %%
test_df.head()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 261         M        17.35         23.06          111.00      933.1
# 367         B        12.21         18.02           78.31      458.4
# 542         B        14.74         25.42           94.70      668.6
# 29          M        17.57         15.05          115.00      955.1
# 476         B        14.20         20.53           92.41      618.4
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 261          0.08662           0.06290         0.02891              0.02837
# 367          0.09231           0.07175         0.04392              0.02027
# 542          0.08275           0.07214         0.04105              0.03027
# 29           0.09847           0.11570         0.09875              0.07953
# 476          0.08931           0.11080         0.05063              0.03058
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 261         0.1564  ...         19.85          31.47           128.20
# 367         0.1695  ...         14.29          24.04            93.85
# 542         0.1840  ...         16.51          32.29           107.40
# 29          0.1739  ...         20.01          19.52           134.90
# 476         0.1506  ...         16.45          27.26           112.10
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 261      1218.0            0.1240             0.1486           0.1211
# 367       624.6            0.1368             0.2170           0.2413
# 542       826.4            0.1060             0.1376           0.1611
# 29       1227.0            0.1255             0.2812           0.2489
# 476       828.5            0.1153             0.3429           0.2512
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 261               0.08235          0.2452                  0.06515
# 367               0.08829          0.3218                  0.07470
# 542               0.10950          0.2722                  0.06956
# 29                0.14560          0.2756                  0.07919
# 476               0.13390          0.2534                  0.07858
#
# [5 rows x 31 columns]

# %%
print("Dimensions van x_train: {}".format(train_df.shape))
print("Dimensions van x_test: {}".format(test_df.shape))
# Out:
# Dimensions van x_train: (427, 31)
# Dimensions van x_test: (142, 31)

# %% [markdown]
# <h2>Bouwen van de model.</h2>

# %% [markdown]
# <p>In deze fase wordt het model geimplementeerd en daarvan de confusion matrix uitgehaald.</p>

# %% [markdown]
# <p>Voor dit algorithm moet de volgende gedaan worden:
#  <ul>
#      <li>tree = decisionTree van train_df bouwen</li>
#      <li>classify = diagnosis voorspellen </li>
#      <li>accuracy = calculate_accuracy(x_test, tree)</li>
# </ul>
# Voor deze algoritme gaan we grotendeels gebruik maken van numpy.
# Er wordt eerst de training dataset van een <i>pandas DataFrame</i> naar een <i>numy array</i> omzetten.
#
# Voor de terminolofy en de wiskundige opzet van de Decision Tree bekijk ......docx
# </p>

# %%
train_df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38           122.8     1001.0
# 2         M        19.69         21.25           130.0     1203.0
# 6         M        18.25         19.98           119.6     1040.0
# 7         M        13.71         20.83            90.2      577.9
# 8         M        13.00         21.82            87.5      519.8
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840            0.2776         0.30010              0.14710
# 2          0.10960            0.1599         0.19740              0.12790
# 6          0.09463            0.1090         0.11270              0.07400
# 7          0.11890            0.1645         0.09366              0.05985
# 8          0.12730            0.1932         0.18590              0.09353
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
# 2         0.2069  ...         23.57          25.53            152.5
# 6         0.1794  ...         22.88          27.66            153.2
# 7         0.2196  ...         17.06          28.14            110.6
# 8         0.2350  ...         15.49          30.73            106.2
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 2      1709.0            0.1444             0.4245           0.4504
# 6      1606.0            0.1442             0.2576           0.3784
# 7       897.0            0.1654             0.3682           0.2678
# 8       739.3            0.1703             0.5401           0.5390
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 2                0.2430          0.3613                  0.08758
# 6                0.1932          0.3063                  0.08368
# 7                0.1556          0.3196                  0.11510
# 8                0.2060          0.4378                  0.10720
#
# [5 rows x 31 columns]

# %%
data_train = train_df.values # convert dataframe x_train in to numpy array
data_train[:5]
# Out:
# array([['M', 17.99, 10.38, 122.8, 1001.0, 0.1184, 0.2776, 0.3001, 0.1471,
#         0.2419, 0.07871, 1.095, 0.9053, 8.589, 153.4, 0.006399, 0.04904,
#         0.05372999999999999, 0.01587, 0.03003, 0.006193, 25.38, 17.33,
#         184.6, 2019.0, 0.1622, 0.6656, 0.7119, 0.2654, 0.4601, 0.1189],
#        ['M', 19.69, 21.25, 130.0, 1203.0, 0.1096, 0.1599, 0.1974, 0.1279,
#         0.2069, 0.059989999999999995, 0.7456, 0.7869, 4.585, 94.03,
#         0.00615, 0.040060000000000005, 0.03832, 0.02058, 0.0225,
#         0.004571, 23.57, 25.53, 152.5, 1709.0, 0.1444, 0.4245, 0.4504,
#         0.243, 0.3613, 0.08757999999999999],
#        ['M', 18.25, 19.98, 119.6, 1040.0, 0.09462999999999999, 0.109,
#         0.1127, 0.07400000000000001, 0.1794, 0.057420000000000006,
#         0.4467, 0.7732, 3.18, 53.91, 0.004314, 0.013819999999999999,
#         0.02254, 0.01039, 0.01369, 0.002179, 22.88, 27.66, 153.2, 1606.0,
#         0.1442, 0.2576, 0.3784, 0.1932, 0.3063, 0.08367999999999999],
#        ['M', 13.71, 20.83, 90.2, 577.9, 0.1189, 0.1645,
#         0.09366000000000001, 0.05985, 0.2196, 0.07451, 0.5835,
#         1.3769999999999998, 3.8560000000000003, 50.96, 0.008805,
#         0.030289999999999997, 0.024880000000000003, 0.014480000000000002,
#         0.01486, 0.005412, 17.06, 28.14, 110.6, 897.0, 0.1654, 0.3682,
#         0.2678, 0.1556, 0.3196, 0.1151],
#        ['M', 13.0, 21.82, 87.5, 519.8, 0.1273, 0.1932, 0.1859, 0.09353,
#         0.235, 0.07389, 0.3063, 1.002, 2.406, 24.32, 0.005731,
#         0.035019999999999996, 0.03553, 0.01226, 0.02143, 0.003749, 15.49,
#         30.73, 106.2, 739.3, 0.1703, 0.5401, 0.539, 0.20600000000000002,
#         0.4378, 0.1072]], dtype=object)

# %%
def check_purity(data):
    'Bepaal of data puur of impuur is'
    target_column = data[:, 0]
    unique_classes = np.unique(target_column)
    #print(unique_classes)

    if len(unique_classes) == 1:
        return True
    return False

# %%
check_purity(data_train)
#Doordat er is sprake van 2 type classe(diagnosis) is de data niet puur
# Out:
# False

# %% [markdown]
# ### classify

# %%
def classify_data(data):
    'Bepaal de unieke klassen en haal uit de meest voorkomende klasse'
    target_column = data[:, 0]
    unique_classes, counts_unique_classes = np.unique(target_column, return_counts = True)
    #print(unique_classes)
    #print(counts_unique_classes)

    index = counts_unique_classes.argmax()
    #argmax(): geeft de index van de maximum element in de array
    classification = unique_classes[index] 
    return classification

# %%
classify_data(data_train)
# Out:
# 'B'

# %% [markdown]
# ### Potential Splits

# %% [markdown]
# <p>
# potential_splits is een dictionary met keys index en value potential <br>
# index_columns zal zijn van train_train[1:]</p>

# %%
def get_potential_splits(data):
    
    potential_splits = {}
    _, n_columns = data.shape # haal uit de aantal kolommmen van data
    
    for columns_index in range(1, n_columns):
        potential_splits[columns_index] = []
        #print(potential_splits)
        values = data[:, columns_index]
        unique_values = np.unique(values)

        for index in range(len(unique_values)):
            if index != 0:
                current_value = unique_values[index]
                previous_value = unique_values[index -1]
                potential_split = (current_value + previous_value)/2

                potential_splits[columns_index].append(potential_split)
    return potential_splits

# %%
potential_splits = get_potential_splits(data_train)

# %%
potential_splits
# Out:
# {1: [7.355,
#   7.7445,
#   8.1655,
#   8.584,
#   8.5975,
#   8.608,
#   8.6445,
#   8.6985,
#   8.73,
#   8.806000000000001,
#   8.883,
#   8.919,
#   8.9895,
#   9.035499999999999,
#   9.1075,
#   9.2205,
#   9.2815,
#   9.314,
#   9.365,
#   9.401,
#   9.414,
#   9.4635,
#   9.535499999999999,
#   9.586500000000001,
#   9.6365,
#   9.6675,
#   9.672,
#   9.6795,
#   9.707,
#   9.7345,
#   9.74,
#   9.7485,
#   9.766000000000002,
#   9.782,
#   9.817,
#   9.8615,
#   9.953,
#   10.04,
#   10.105,
#   10.17,
#   10.19,
#   10.23,
#   10.274999999999999,
#   10.305,
#   10.379999999999999,
#   10.46,
#   10.485,
#   10.5,
#   10.54,
#   10.585,
#   10.625,
#   10.68,
#   10.73,
#   10.775,
#   10.83,
#   10.870000000000001,
#   10.91,
#   10.95,
#   11.0,
#   11.05,
#   11.07,
#   11.105,
#   11.135000000000002,
#   11.145,
#   11.175,
#   11.21,
#   11.235,
#   11.254999999999999,
#   11.265,
#   11.274999999999999,
#   11.285,
#   11.295,
#   11.315000000000001,
#   11.335,
#   11.35,
#   11.364999999999998,
#   11.39,
#   11.42,
#   11.44,
#   11.455,
#   11.465,
#   11.48,
#   11.495000000000001,
#   11.504999999999999,
#   11.515,
#   11.53,
#   11.555,
#   11.585,
#   11.605,
#   11.614999999999998,
#   11.625,
#   11.645,
#   11.665,
#   11.675,
#   11.69,
#   11.705,
#   11.725000000000001,
#   11.745000000000001,
#   11.754999999999999,
#   11.780000000000001,
#   11.82,
#   11.844999999999999,
#   11.86,
#   11.879999999999999,
#   11.895,
#   11.915,
#   11.934999999999999,
#   11.945,
#   11.969999999999999,
#   11.995000000000001,
#   12.015,
#   12.035,
#   12.045,
#   12.06,
#   12.085,
#   12.14,
#   12.184999999999999,
#   12.195,
#   12.215,
#   12.24,
#   12.26,
#   12.285,
#   12.305,
#   12.325,
#   12.35,
#   12.379999999999999,
#   12.425,
#   12.455,
#   12.465,
#   12.48,
#   12.515,
#   12.55,
#   12.57,
#   12.6,
#   12.625,
#   12.64,
#   12.66,
#   12.675,
#   512.95,
#   513.85,
#   514.15,
#   514.4,
#   515.2,
#   516.15,
#   516.5,
#   518.0,
#   519.5999999999999,
#   519.9,
#   520.1,
#   522.0,
#   524.5,
#   525.8,
#   526.8,
#   528.3,
#   529.8,
#   530.4000000000001,
#   531.05,
#   534.2,
#   537.0999999999999,
#   537.8499999999999,
#   538.55,
#   538.8,
#   540.3499999999999,
#   542.3499999999999,
#   544.05,
#   545.6500000000001,
#   546.2,
#   546.3499999999999,
#   549.4,
#   552.95,
#   554.3,
#   555.9000000000001,
#   557.4000000000001,
#   558.6500000000001,
#   560.1,
#   561.55,
#   563.75,
#   565.8499999999999,
#   568.65,
#   571.05,
#   571.45,
#   572.05,
#   572.45,
#   572.9000000000001,
#   574.25,
#   575.4,
#   576.7,
#   578.0999999999999,
#   578.5999999999999,
#   579.0,
#   579.85,
#   581.6500000000001,
#   583.75,
#   585.3499999999999,
#   587.4,
#   589.45,
#   591.3,
#   593.1500000000001,
#   593.95,
#   595.05,
#   596.25,
#   598.05,
#   599.95,
#   601.65,
#   603.15,
#   604.95,
#   607.8,
#   609.5,
#   610.55,
#   613.85,
#   620.2,
#   626.8499999999999,
#   629.8499999999999,
#   631.45,
#   633.05,
#   636.6,
#   640.4000000000001,
#   640.95,
#   641.85,
#   642.6,
#   643.45,
#   644.5,
#   645.25,
#   646.95,
#   649.6,
#   651.45,
#   654.0,
#   656.25,
#   656.65,
#   657.8499999999999,
#   659.25,
#   662.2,
#   664.8,
#   666.5999999999999,
#   668.5,
#   670.05,
#   672.55,
#   674.25,
#   676.45,
#   679.4000000000001,
#   680.8,
#   681.7,
#   683.5,
#   685.7,
#   687.0999999999999,
#   688.3499999999999,
#   689.45,
#   689.85,
#   691.95,
#   696.25,
#   700.3499999999999,
#   706.25,
#   711.2,
#   712.3,
#   713.05,
#   714.95,
#   716.75,
#   718.2,
#   723.85,
#   729.75,
#   731.8499999999999,
#   734.65,
#   740.9,
#   746.05,
#   752.9000000000001,
#   759.95,
#   761.5,
#   764.1500000000001,
#   770.05,
#   778.05,
#   785.55,
#   790.85,
#   795.5,
#   798.3,
#   799.4,
#   802.55,
#   806.1500000000001,
#   808.5,
#   811.75,
#   814.75,
#   817.8,
#   823.3,
#   829.8499999999999,
#   836.65,
#   849.0,
#   857.85,
#   863.8,
#   874.85,
#   883.25,
#   890.65,
#   897.15,
#   901.8,
#   908.5,
#   915.6500000000001,
#   919.6,
#   924.4000000000001,
#   928.25,
#   928.55,
#   929.0999999999999,
#   930.15,
#   939.45,
#   964.25,
#   981.05,
#   981.8,
#   983.3,
#   987.3,
#   991.05,
#   993.05,
#   996.45,
#   999.95,
#   1003.5,
#   1015.0,
#   1032.0,
#   1046.0,
#   1060.0,
#   1071.5,
#   1075.5,
#   1076.5,
#   1082.5,
#   1090.0,
#   1093.0,
#   1098.0,
#   1103.0,
#   1107.0,
#   1116.5,
#   1126.5,
#   1131.0,
#   1135.0,
#   1141.5,
#   1146.5,
#   1150.0,
#   1153.5,
#   1156.0,
#   1159.5,
#   1164.5,
#   0.09207,
#   0.092085,
#   0.092135,
#   0.092195,
#   0.09231,
#   0.09246000000000001,
#   0.09256,
#   0.092655,
#   0.09279,
#   0.09294,
#   0.09313,
#   0.09329499999999999,
#   0.09340999999999999,
#   0.09351000000000001,
#   0.09356,
#   0.093705,
#   0.09409999999999999,
#   0.094415,
#   0.094545,
#   0.094665,
#   0.09473999999999999,
#   0.09498999999999999,
#   0.09551499999999999,
#   0.095845,
#   0.095995,
#   0.09616,
#   0.09628,
#   0.09642,
#   0.096585,
#   0.096955,
#   0.0973,
#   0.09756000000000001,
#   0.09777,
#   0.097855,
#   0.09806999999999999,
#   0.09847500000000001,
#   0.09873,
#   0.098775,
#   0.09904,
#   0.099335,
#   0.09945000000000001,
#   0.09958,
#   0.10006999999999999,
#   0.1006,
#   0.1008,
#   0.10095,
#   0.10114999999999999,
#   0.10135,
#   0.1015,
#   0.10164999999999999,
#   0.1018,
#   0.1021,
#   0.10250000000000001,
#   0.10285,
#   0.10305,
#   0.1032,
#   0.10335,
#   0.10350000000000001,
#   0.1037,
#   0.10405,
#   0.1046,
#   0.10519999999999999,
#   0.10569999999999999,
#   0.1061,
#   0.10635,
#   0.10644999999999999,
#   0.1066,
#   0.1069,
#   0.10715,
#   0.1074,
#   0.1078,
#   0.1081,
#   0.10830000000000001,
#   0.1089,
#   0.1101,
#   0.11085,
#   0.1116,
#   0.11274999999999999,
#   0.1137,
#   0.11465,
#   0.11595,
#   0.11715,
#   0.1179,
#   0.11860000000000001,
#   0.119,
#   0.11945,
#   0.1199,
#   0.1202,
#   0.12045,
#   0.12145,
#   0.12285,
#   0.12365000000000001,
#   0.12415,
#   0.12459999999999999,
#   0.12505,
#   0.12555,
#   0.1267,
#   0.1286,
#   0.1318,
#   0.134,
#   0.13524999999999998,
#   0.13829999999999998,
#   0.14024999999999999,
#   0.14040000000000002,
#   0.1407,
#   0.14200000000000002,
#   0.14385]}

# %% [markdown]
# <p>Visualiseer de potential_splits van de values kolommen met behulp van de lmplot<br>
# Er een voorbeeld gepot van de splits van de kolommen radius_mean en texture_mean</p>

# %%
# Visualiseer de potential splits van raius_mean
sns.lmplot(data = train_df, hue = 'diagnosis', x = 'radius_mean', y = 'texture_mean', 
           fit_reg = False, height = 6, aspect = 1.5)

plt.vlines(x = potential_splits[1], ymin = 10, ymax = 40)

# %%
# Visualiseer de potential splits van texture_mean
sns.lmplot(data = train_df, hue = 'diagnosis', x = 'radius_mean', y = 'texture_mean', 
           fit_reg = False, height = 6, aspect = 1.5)

plt.hlines(y = potential_splits[2], xmin =10, xmax = 30)

# %% [markdown]
# ### Split data
# <p>Bij een bepaalde vraag van de Decision tree moet de data gescheiden van data_below  of data_above</p>

# %%
def split_data(data, split_column, split_value):
    split_column_value= data[:, split_column]
    data_below = data[split_column_value <= split_value]
    data_above = data[split_column_value  > split_value]
    return data_below, data_above

# %%
train_df.head(10)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M        17.99         10.38          122.80     1001.0
# 2          M        19.69         21.25          130.00     1203.0
# 6          M        18.25         19.98          119.60     1040.0
# 7          M        13.71         20.83           90.20      577.9
# 8          M        13.00         21.82           87.50      519.8
# 10         M        16.02         23.24          102.70      797.8
# 12         M        19.17         24.80          132.40     1123.0
# 14         M        13.73         22.61           93.60      578.3
# 15         M        14.54         27.54           96.73      658.8
# 16         M        14.68         20.13           94.74      684.5
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760         0.30010              0.14710
# 2           0.10960           0.15990         0.19740              0.12790
# 6           0.09463           0.10900         0.11270              0.07400
# 7           0.11890           0.16450         0.09366              0.05985
# 8           0.12730           0.19320         0.18590              0.09353
# 10          0.08206           0.06669         0.03299              0.03323
# 12          0.09740           0.24580         0.20650              0.11180
# 14          0.11310           0.22930         0.21280              0.08025
# 15          0.11390           0.15950         0.16390              0.07364
# 16          0.09867           0.07200         0.07395              0.05259
#
#     symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0          0.2419  ...         25.38          17.33            184.6
# 2          0.2069  ...         23.57          25.53            152.5
# 6          0.1794  ...         22.88          27.66            153.2
# 7          0.2196  ...         17.06          28.14            110.6
# 8          0.2350  ...         15.49          30.73            106.2
# 10         0.1528  ...         19.19          33.88            123.8
# 12         0.2397  ...         20.96          29.94            151.7
# 14         0.2069  ...         15.03          32.01            108.8
# 15         0.2303  ...         17.46          37.13            124.1
# 16         0.1586  ...         19.07          30.88            123.4
#
#     area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       2019.0            0.1622             0.6656           0.7119
# 2       1709.0            0.1444             0.4245           0.4504
# 6       1606.0            0.1442             0.2576           0.3784
# 7        897.0            0.1654             0.3682           0.2678
# 8        739.3            0.1703             0.5401           0.5390
# 10      1150.0            0.1181             0.1551           0.1459
# 12      1332.0            0.1037             0.3903           0.3639
# 14       697.7            0.1651             0.7725           0.6943
# 15       943.2            0.1678             0.6577           0.7026
# 16      1138.0            0.1464             0.1871           0.2914
#
#     concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.26540          0.4601                  0.11890
# 2                0.24300          0.3613                  0.08758
# 6                0.19320          0.3063                  0.08368
# 7                0.15560          0.3196                  0.11510
# 8                0.20600          0.4378                  0.10720
# 10               0.09975          0.2948                  0.08452
# 12               0.17670          0.3176                  0.10230
# 14               0.22080          0.3596                  0.14310
# 15               0.17120          0.4218                  0.13410
# 16               0.16090          0.3029                  0.08216
#
# [10 rows x 31 columns]

# %%
split_column, split_value = (1,18)
data_below, data_above = split_data(data_train, split_column, split_value)

# %%
plotting_df =pd.DataFrame(data_train, columns = df.columns)
sns.lmplot(data= plotting_df, x='radius_mean', y= 'texture_mean',hue ='diagnosis' ,fit_reg=False, height =6, aspect=1.5)
plt.vlines(x= split_value, ymin= 8, ymax = 40)
#plt.hlines(y = split_value, xmin=10, xmax= 28)

# %%
def calculate_entropy(data):
    
    label_column = data[:, 0]
    _, counts = np.unique(label_column, return_counts=True)

    probabilities = counts / counts.sum()
    entropy = sum(probabilities * -np.log2(probabilities))
     
    return entropy

# %%
calculate_entropy(data_above)
# Out:
# 0.0

# %%
def calculate_overall_entropy(data_below, data_above):
    
    n = len(data_below) + len(data_above)
    p_data_below = len(data_below) / n
    p_data_above = len(data_above) / n

    overall_entropy =  (p_data_below * calculate_entropy(data_below) 
                      + p_data_above * calculate_entropy(data_above))
    
    return overall_entropy

# %%
def determine_best_split(data, potential_splits):
    'Bepaal de beste split, dus de split met de kleinste overall entropy'
    overall_entropy = 9999
    for column_index in potential_splits:
        for value in potential_splits[column_index]:
            data_below, data_above = split_data(data, split_column=column_index, split_value=value)
            current_overall_entropy = calculate_overall_entropy(data_below, data_above)

            if current_overall_entropy <= overall_entropy:
                overall_entropy = current_overall_entropy
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### Algoritme

# %%
def decision_tree_algorithm(df, counter=0, min_samples=2, max_depth=5): 
    
    # data preparations
    if counter == 0:
        global COLUMN_HEADERS
        temp = []
        #replace onnodige " " naar "_"
        for i in df.columns:
            temp.append( i.replace(" ", "~~~"))# Ama was here!!
        COLUMN_HEADERS = temp
        data = df.values
    else:
        data = df           
    
    
    # base cases
    if (check_purity(data)) or (len(data) < min_samples) or (counter == max_depth):
        classification = classify_data(data)
        
        return classification

    
    # recursive part
    else:    
        counter += 1

        
        potential_splits = get_potential_splits(data)
        split_column, split_value = determine_best_split(data, potential_splits)
        data_below, data_above = split_data(data, split_column, split_value)
        
        # instantiate node 
        feature_name = COLUMN_HEADERS[split_column]
        question = "{} <= {}".format(feature_name, split_value)
        sub_tree = {question: []}
        
        # find answers (recursion)
        yes_answer = decision_tree_algorithm(data_below, counter, min_samples, max_depth)
        no_answer = decision_tree_algorithm(data_above, counter, min_samples, max_depth)
        
        # If the answers are the same, then there is no point in asking the qestion.
        # This could happen when the data is classified even though it is not pure
        # yet (min_samples or max_depth base cases).
        
        # create leaf
        if yes_answer == no_answer:
            sub_tree = yes_answer
        else:
            #create node
            sub_tree[question].append(yes_answer)
            sub_tree[question].append(no_answer)
        
        return sub_tree

# %%
tree = decision_tree_algorithm(train_df, max_depth=3)
tree
# Out:
# {'perimeter_worst <= 104.1': ['B',
#   {'concave~~~points_worst <= 0.15075': [{'texture_mean <= 18.785': ['B',
#       'M']},
#     'M']}]}

# %% [markdown]
# ##### Aan de hand van de decision_tree_algoritme wordt kunnen we de diagnosis voorspellen .Hier gaan we de test dataset gebruiken

# %%
def classify_example(example, tree):
    question = list(tree.keys())[0]
    feature_name, comparison_operator, value = question.split()

    # ask question
    if example[feature_name.replace("~~~", " ")] <= float(value): 
        answer = tree[question][0]
    else:
        answer = tree[question][1]

    # base case
    if not isinstance(answer, dict):
        return answer
    
    # recursive part
    else:
        residual_tree = answer
        return classify_example(example, residual_tree)

# %%
test_df.head()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 261         M        17.35         23.06          111.00      933.1
# 367         B        12.21         18.02           78.31      458.4
# 542         B        14.74         25.42           94.70      668.6
# 29          M        17.57         15.05          115.00      955.1
# 476         B        14.20         20.53           92.41      618.4
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 261          0.08662           0.06290         0.02891              0.02837
# 367          0.09231           0.07175         0.04392              0.02027
# 542          0.08275           0.07214         0.04105              0.03027
# 29           0.09847           0.11570         0.09875              0.07953
# 476          0.08931           0.11080         0.05063              0.03058
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 261         0.1564  ...         19.85          31.47           128.20
# 367         0.1695  ...         14.29          24.04            93.85
# 542         0.1840  ...         16.51          32.29           107.40
# 29          0.1739  ...         20.01          19.52           134.90
# 476         0.1506  ...         16.45          27.26           112.10
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 261      1218.0            0.1240             0.1486           0.1211
# 367       624.6            0.1368             0.2170           0.2413
# 542       826.4            0.1060             0.1376           0.1611
# 29       1227.0            0.1255             0.2812           0.2489
# 476       828.5            0.1153             0.3429           0.2512
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 261               0.08235          0.2452                  0.06515
# 367               0.08829          0.3218                  0.07470
# 542               0.10950          0.2722                  0.06956
# 29                0.14560          0.2756                  0.07919
# 476               0.13390          0.2534                  0.07858
#
# [5 rows x 31 columns]

# %%
lst_predicted= []
lst_actual = []

for i in range(len(test_df)):    
    lst_predicted.append(classify_example(test_df.iloc[i], tree))
    lst_actual.append(test_df['diagnosis'].iloc[i])

print('Voorspelde diagnosis van test_df')
print(lst_predicted)
print()
print('Werkelijke diagnosis van test_df')
print(lst_actual)
# Out:
# Voorspelde diagnosis van test_df
# ['M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B']
#
# Werkelijke diagnosis van test_df
# ['M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'B']

# %% [markdown]
# ###### Hiermee zullen we de twee lijsten  diagnosis gaan visualiseren

# %%
#Diagnosis die classify_example had voorspelt
predicted_diagnosis = lst_predicted
sns.countplot(np.array(predicted_diagnosis))

# %%
#Werkelijke diagnose van test_df
actual_diagnosis = lst_actual
sns.countplot(np.array(actual_diagnosis ))

# %% [markdown]
# #### De nauwkerigheid van de algoritme bepalen

# %%
def calculate_accuracy(df, tree):

    df["classification"] = df.apply(classify_example, axis=1, args=(tree,))
    #print(df["classification"])
    df["classification_correct"] = df["classification"] == df["diagnosis"]
    correct = []
    for i in df["classification_correct"]:
        if i == True:
            correct.append(i)
    gem = len(correct)/ len(df["classification_correct"])
    
    accuracy = df["classification_correct"].mean()
    
    return accuracy

# %%
accuracy = calculate_accuracy(test_df, tree)
print("Accuracy: {} %".format(accuracy *100))
# Out:
# Accuracy: 88.73239436619718 %

# %% [markdown]
# ## Aplication: Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(actual_diagnosis, predicted_diagnosis)
print(type(cm))
TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]

change_order_cm = np.array([[TN, TP],[FN, FP]])
  
print(change_order_cm)
print('Model Decision Tree Classifier  Testing Accuracy = "{}%"'.format(((TP + TN) / (TP + TN + FN + FP))*100))
print()# Print a new line

confusion = pd.DataFrame(change_order_cm, index = ['True', 'False'],
                         columns = ['negative', 'positive'])
#print confusion matrix in de vorm van een tabel
confusion
# Out:
# <class 'numpy.ndarray'>
# [[81 45]
#  [12  4]]
# Model Decision Tree Classifier  Testing Accuracy = "88.73239436619718%"
#        negative  positive
# True         81        45
# False        12         4

# %% [markdown]
# #### <p>Er is te zien dat dit model een nauwkeurig voorspelling van ongeveer 88,7% geeft.<br>
# Aan de hand van de confusion matrix, wordt er bepaald dat er is sprake van 4 <i>false positve</i> en 12 <i>false negative</i>
# </p>

# %%
#confusion matrix visualiseren in een heatmap
sns.heatmap(confusion, annot=True)
